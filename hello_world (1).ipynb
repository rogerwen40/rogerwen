# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Fri Aug 21 23:53:08 2020

@author: JasonChang
"""

import numpy as np
import matplotlib.pyplot as plt

def add(a, b):
    
    c = a + b
    
    return c

###
#減法
###

def sub(a , b):

  c = a - b

  return c


###
#乘法
###




###
#除法
###



###
#2x+3y
###

# %%
dat_in = np.arange(1,10)
print(dat_in)
# Out:
# [1 2 3 4 5 6 7 8 9]

# %%
dat_out = add(dat_in,2)
print(dat_out)
# Out:
# [ 3  4  5  6  7  8  9 10 11]

# %%
dat_sub = sub(dat_in,8)
print(dat_sub)
# Out:
# [-7 -6 -5 -4 -3 -2 -1  0  1]

# %%
plt.plot(dat_in,label='in')
plt.plot(dat_out,label='out')
plt.plot(dat_sub, label = 'sub')
plt.legend()
plt.rcParams['figure.figsize'] = [50, 25]
plt.show
# Out:
# <function matplotlib.pyplot.show>
